# %%
import numpy as np
import matplotlib.pyplot as plt
import interpolate_exp_cos as p1
import sin_deriv as p2
import integrate_exp as p3
import diff_functions as p4

# %% [markdown]
# # Problem 1: Interpolate a Discrete Function
# Interpolates values for a function give in B.1

# %%
p1.run()
# Out:
# q = 2.0
# Approximation of f(-0.45):  0.715545748527
# Exact value of f(-0.45):  -0.434965534111
# Eror in approximation:  -1.15051128264
#
# q = 4.0
# Approximation of f(-0.45):  -0.893468805496
# Exact value of f(-0.45):  -0.434965534111
# Eror in approximation:  0.458503271384
#
# q = 8.0
# Approximation of f(-0.45):  0.367879441171
# Exact value of f(-0.45):  -0.434965534111
# Eror in approximation:  -0.802844975283
#
# q = 16.0
# Approximation of f(-0.45):  -3.15681784199
# Exact value of f(-0.45):  -0.434965534111
# Eror in approximation:  2.72185230788

# %% [markdown]
# # Problem 2: Graphs a function with different parameters
# f(x) = sin(1/x+e)

# %%
p2.run(50, 1/5.0)

# %% [markdown]
# ### Run the program to determine how many n is required for an accuracy of < 0.1 (n is printed out)

# %%
p2.run2(1/5.0)
# Out:
# 112

# %%
p2.run2(1/10.0)
# Out:
# 224

# %%
p2.run2(1/20.0)
# Out:
# 474

# %% [markdown]
# ## Seems that a good estimate is around... n = 20*e

# %% [markdown]
# # Problem 3: Implements the trapezoidal method
# Rows correspond to n values of [100,200,300,400,500] columns correspond to L values of [2,4,6,8,10]

# %%
p3.run()
# Out:
# I: 1.76415789768, Error: -0.00829595322543 I: 1.77245382334, Error: -2.75660823057e-08 I: 1.77245385091, Error: 0.0 I: 1.77245385091, Error: -6.66133814775e-16 I: 1.77245385091, Error: -1.33226762955e-15
# I: 1.7641615605, Error: -0.00829229040291 I: 1.77245382352, Error: -2.73863745015e-08 I: 1.77245385091, Error: 6.66133814775e-16 I: 1.77245385091, Error: 0.0 I: 1.77245385091, Error: 1.11022302463e-15
# I: 1.76416223884, Error: -0.00829161206225 I: 1.77245382355, Error: -2.73530469386e-08 I: 1.77245385091, Error: -6.66133814775e-16 I: 1.77245385091, Error: -6.66133814775e-16 I: 1.77245385091, Error: 4.4408920985e-16
# I: 1.76416247627, Error: -0.00829137464005 I: 1.77245382356, Error: -2.73413782725e-08 I: 1.77245385091, Error: -6.66133814775e-16 I: 1.77245385091, Error: -6.66133814775e-16 I: 1.77245385091, Error: 6.66133814775e-16
# ...

# %% [markdown]
# # Problem 4: Functions vs their derivatives
# Plots a function and the numerical der

# %%
p4.run()
